# %% [markdown]
# # Logical Function & Lookup
# 1.Write a formula to check if the marks in cell B2 are greater than or equal to 40. If yes, return "pass" , otherwise "Fail".
# - Step !: Formula the if condition
#
# The problem asks for a formula in a spreadsheet application (like Excel) to check the value in cell B2. The condition is whether the value is greater than or equal to 40.if true, the result should be "pass";otherwise, it should be "Fail".This can be represented using the logical if function:
#
# =IF(B2>=40, "pass","Fail")
#
# 2.A company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not.
# - Step 1: Formulate the conditions for bonus eligibility
#
# An employee gets a bonus if two conditions are met: sales are above 40,000 AND attendance is greater than or equal to 90%. Assuming sales are in cell B2 and attendance in cell C2, the conditions are B2>40000 and C2>90%.
#
# Step 2: Combine conditions using the AND function
#
# Both conbine must be true,so the AND function is used: AND(B2>40000,C2>90%).
#
# Step 3: Define the outcomes
#
# If both conditions are true,the employee gets a bonus 9"Yes" or similar positive indicator). If not, they do not ("No" or similer negative indicator).
#
# Step 4: Construct the final formula
#
# Using the IF and AND functions, the formula to return "Yes" for bonus and "No" otherwise is:
#
# =IF(AND(B2>40000,C2>=90%),"Yes","No")
#
# 3.Write a nested IF formula:
# - Step 1: Write a nested IF formula
#
# The formula for cell B2, based on the conditions provided, is:
#
# =IF(B2>=90, "A", IF(B2>=75, "B", IF(B2>=50,"C","Fail")))
#
# 4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
# - Step 1: Identify the department
#
# The table shows that the empoloyee with EmpIDE103 is in the Finance department.
#
# Step 2:Explain the LOOKUP function
#
# A VLOOKUP function is used beacause the data is organized vertically, and the lookup value (EmpID) is in the first column of the table arry. The function searches for the specific EmplID in the first column and returns yhe value from the corresponding row in the specified column (Department).
#
# The department for Employee ID E103 is Finace. The VLOOKUP function is used for this task because the lookup data is arranged in a vertical table structure, with the unique identifier (EmpID) in the leftmost column.
#
# 5.A company has set the following commission structure for its sales team:
# - Step 1: Identify the commission structure and sales amount
#
# The commission structure is provided in a table.
# The salesperson achieved sales of 45,000.
#
# Step 2: Use VLOOKUP to find the applicable rate
#
# Using the VLOOKUP function with an approximate match, the function looks for the largest value in the first column that is less than or equal to the lookup value (45,000).
#
# The value 20,000 is the largest amount that is less than 45,000 in the table. The corresponding commission rate for 20,000 is 10%.
#
# The commission rate applicable is 10%.
#
# 6.The HR department maintains the following leave records of employees:onus or not .
# - Step 1: Formulate the IF function
#
# The problem asks for an IF function to check if Leaves Taken is greater than Leaves Allowed. If true, display "Exceeded", otherwise "OK".
#
# Step 2: Apply the function to the data
#
# Assuming Leaves Taken is in column B and Leaves Allowed is in column C, starting from row 2, the formula for Alex would be:
#
# =IF(B2>C2, "Exceeded", "OK")
#
# Applying this to each employee:
# - For Alex: =IF(10>12,"Exceeded", "OK") which evaliates to "OK".
# - For Bod: =IF(10>15, "Exceeded","OK") which evaluates to "OK".
# - For Anna: =IF(8>12,"Exceeded", "OK") which evaluates to"OK".
#
# The IF function to solve the problem is =IF(B2>C2,"Exceeded", "OK") (assumingB2 and C2 are the first datacells).
#
# 7.Find the salary of EmpID = E105 using INDEX-MATCH Function.
# - Step 1: Understand INDEX-MATCH
#
# The INDEX function returns a value at a given position in a range, while MACH returns the relative position of an item in a range. Combined, they can look up a value.
#
# The general formula is:
#
# =INDEX(return_range,MATCH(LOOKUP_value, Lookup_range, 0)).
#
# Step 2: Identify ranges and lookup value
#
# - Lookup_value:"E105"
# - Lookup_range(EmpID column): A range like A2:A5
# - return_range(Salery column): A range like B2,B5
#
# Step 3: Formulate the function
#
# The function to find the salery for "E105"is: =INDEX(B2:B5,MATCH("E105",A2:A5,0))
#
# Step 4: Evaluate the function
# - MATCH("E105",A2:A5,0) finds "E105" in the second position of the EmpID list.
# - INDEX(B2:B5,2) returns the value in the second position of the Salary list, which is 72000.
#
# The salery of EmpID E105 is 72000. The function used is =INDEX(B2:B5,MATCH("E105",A2:A5,0)).
#
# 8.U se the XLOOKUP function to find the Department of the employee with Emp ID = E303.
# - Step 1: Understand XLOOKUP
#
# The XLOOKUP function searches a ranse or an arrey for a match and returns the corresponding item from a second range or array.
#
# The general formula is:
# =XLOOKUP(lookup_vale, lookup_array, return_array,[if_not_found],[match_mode],[search_mode]).
#
# Step 2: Identify ranges and lookup value
# - lookup_value:"E303"
# - lookup_array (EmpID column): A range like A2:A5
# - return_array (Department column):A range like B2:B5
#
# Step 3: Formulate the function
#
# The function to find the department for "E303"is:
# =XLOOKUP("E303",A2:A5, B2:B5
#
# Step 4: Evaluate the function
# - XLOOKUP("E303',A2:A5,B2:B5)
# searches for "E303",in the first column and return the corresponding value from the second colum,n, which is "IT".
#
# The department for EmpID E303 is IT. The function used is =XLOOKUP("E303",A2:A5,B2:B5).

# %%
# question
'''
this is answer
'''
"""
this is answer
"""
